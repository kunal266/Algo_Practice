# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal266/Algo_Practice/blob/main/yolov3_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="k9JVDUZnx6K9YrcnFDzY")
project = rf.workspace().project("biggjgjgjgjg")
dataset = project.version(1).download("tfrecord")
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="████████████████████")
project = rf.workspace().project("biggjgjgjgjg")
dataset = project.version(1).download("tfrecord")
# Out:
# ...
#      |████████████████████████████████| 178 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 45.5 MB/s
# ...
#      |████████████████████████████████| 138 kB 44.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.8 MB/s
# ...
#      |████████████████████████████████| 62 kB 750 kB/s
# ...
#   Created wheel for roboflow: filename=roboflow-0.1.8-py3-none-any.whl size=20082 sha256=5f989244af1a7787d8d56e91e17e6b97f30f06e2d33b237850f7fcc4ce4921f5
#   Stored in directory: /root/.cache/pip/wheels/db/11/cc/728f5aaa27dd0a16f49c73090f1ef72ba4701c4c0999eba381
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=5f5cb52e7c043a76a82e3d3ede1dbde231dc5853a582fe0dcdaa510a76f54c80
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built roboflow wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
# ...

# %%
# !cat /content/biggjgjgjgjg-1/train/letters_label_map.pbtxt

# %%
# !git clone https://github.com/zzh8829/yolov3-tf2.git
# Out:
# Cloning into 'yolov3-tf2'...
# remote: Enumerating objects: 433, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 433 (delta 7), reused 2 (delta 0), pack-reused 412
# Receiving objects: 100% (433/433), 4.24 MiB | 1.77 MiB/s, done.
# Resolving deltas: 100% (244/244), done.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O yolov3.weights
# Out:
# --2021-11-03 04:08:10--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  23.4MB/s    in 11s
#
# 2021-11-03 04:08:22 (21.4 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
cd yolov3-tf2/
# Out:
# /content/yolov3-tf2

# %%
# !python convert.py --weights /content/yolov3.weights --output /content/yolov3-tf2/checkpoints/yolov3.tf

# %%
# !cat detect.py
# Out:
# import time
# from absl import app, flags, logging
# from absl.flags import FLAGS
# import cv2
# import numpy as np
# import tensorflow as tf
# from yolov3_tf2.models import (
#     YoloV3, YoloV3Tiny
# )
# from yolov3_tf2.dataset import transform_images, load_tfrecord_dataset
# from yolov3_tf2.utils import draw_outputs
#
# flags.DEFINE_string('classes', './data/coco.names', 'path to classes file')
# flags.DEFINE_string('weights', './checkpoints/yolov3.tf',
#                     'path to weights file')
# flags.DEFINE_boolean('tiny', False, 'yolov3 or yolov3-tiny')
# flags.DEFINE_integer('size', 416, 'resize images to')
# flags.DEFINE_string('image', './data/girl.png', 'path to input image')
# flags.DEFINE_string('tfrecord', None, 'tfrecord instead of image')
# flags.DEFINE_string('output', './output.jpg', 'path to output image')
# flags.DEFINE_integer('num_classes', 80, 'number of classes in the model')
#
#
# def main(_argv):
# ...

# %%
# !python detect.py --weights /content/yolov3-tf2/checkpoints/yolov3_train_10.tf --classes /content/biggjgjgjgjg-1/classes.names --image /content/yolov3-tf2/data/10.1.1.193.1819_5.jpg --output /content/yolov3-tf2/data/output_epoch_10.jpg
# Out:
# 2021-11-03 05:44:48.088018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-03 05:44:48.099112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-03 05:44:48.099954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-03 05:44:48.114570: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
output = cv2.imread("/content/yolov3-tf2/data/output_epoch_10.jpg")
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=RGB size=793x1123 at 0x7F7C02B98850>

# %%
ls
# Out:
# checkpoints/     convert.py       docs/       requirements-gpu.txt  train.py
# colab_gpu.ipynb  data/            LICENSE     requirements.txt      yolov3_tf2/
# conda-cpu.yml    detect.py        output.jpg  setup.py
# conda-gpu.yml    detect_video.py  README.md   tools/

# %%
# !cat train.py

# %%
# !cat /content/biggjgjgjgjg-1/test/letters_label_map.pbtxt

# %%
# !python train.py --batch_size 8 --dataset /content/biggjgjgjgjg-1/train/letters.tfrecord --val_dataset /content/biggjgjgjgjg-1/test/letters.tfrecord --epochs 10 --mode eager_tf --transfer fine_tune --classes /content/biggjgjgjgjg-1/classes.names
# Out:
# I1103 04:58:00.567073 140678785136512 train.py:169] 9_train_32, 119.66715240478516, [22.80986, 63.853348, 21.34355]
# I1103 04:58:02.165732 140678785136512 train.py:169] 9_train_33, 82.97765350341797, [36.08612, 11.488514, 23.740702]
# I1103 04:58:03.745345 140678785136512 train.py:169] 9_train_34, 105.37352752685547, [40.85073, 42.359444, 10.499227]
# I1103 04:58:05.295663 140678785136512 train.py:169] 9_train_35, 83.19200897216797, [38.630432, 27.611656, 5.284018]
# I1103 04:58:06.918423 140678785136512 train.py:169] 9_train_36, 76.04519653320312, [19.704756, 28.966915, 15.705415]
# I1103 04:58:08.637383 140678785136512 train.py:169] 9_train_37, 96.07339477539062, [39.095688, 39.68181, 5.6254034]
# I1103 04:58:10.207329 140678785136512 train.py:169] 9_train_38, 58.522544860839844, [19.391602, 17.23413, 10.223517]
# I1103 04:58:11.746674 140678785136512 train.py:169] 9_train_39, 101.49829864501953, [37.61079, 24.488417, 27.72292]
# ...

# %%
# !zip -r /content/biggjgjgjgjg.zip /content/biggjgjgjgjg-1

# %%
ls -sh /content/yolov3-tf2/checkpoints
# Out:
# total 4.2G
# 4.0K checkpoint
# 237M yolov3.tf.data-00000-of-00001
#  24K yolov3.tf.index
# 400M yolov3_train_10.tf.data-00000-of-00001
#  36K yolov3_train_10.tf.index
# 400M yolov3_train_1.tf.data-00000-of-00001
#  36K yolov3_train_1.tf.index
# 400M yolov3_train_2.tf.data-00000-of-00001
#  36K yolov3_train_2.tf.index
# 400M yolov3_train_3.tf.data-00000-of-00001
#  36K yolov3_train_3.tf.index
# 400M yolov3_train_4.tf.data-00000-of-00001
#  36K yolov3_train_4.tf.index
# 400M yolov3_train_5.tf.data-00000-of-00001
#  36K yolov3_train_5.tf.index
# 400M yolov3_train_6.tf.data-00000-of-00001
#  36K yolov3_train_6.tf.index
# 400M yolov3_train_7.tf.data-00000-of-00001
#  36K yolov3_train_7.tf.index
# 400M yolov3_train_8.tf.data-00000-of-00001
#  36K yolov3_train_8.tf.index
# 400M yolov3_train_9.tf.data-00000-of-00001
#  36K yolov3_train_9.tf.index
