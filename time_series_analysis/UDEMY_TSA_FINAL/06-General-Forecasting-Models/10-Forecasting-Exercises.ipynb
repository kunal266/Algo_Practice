# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='https://github.com/kunal266/Algo_Practice/blob/main/time_series_analysis/UDEMY_TSA_FINAL/Pierian_Data_Logo.png?raw=1'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Forecasting Exercises
# This exercise walks through a SARIMA prediction and forecast similar to the one done on the Mauna Loa CO₂ dataset.<br>
# This time we're using a seasonal time series of California Hospitality Industry Employees.
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install pmdarima

# %%
# RUN THIS CELL
import pandas as pd
import numpy as np
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders

# Load specific evaluation tools
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# Load datasets
df = pd.read_csv('/content/drive/MyDrive/UDEMY_TSA_FINAL/Data/HospitalityEmployees.csv',index_col='Date',parse_dates=True)
df.index.freq = 'MS'
print(len(df))
print(df.head())
# Out:
# 348
#             Employees
# Date
# 1990-01-01     1064.5
# 1990-02-01     1074.5
# 1990-03-01     1090.0
# 1990-04-01     1097.4
# 1990-05-01     1108.7

# %% [markdown]
# So <tt>df</tt> has 348 records and one column. The data represents the number of employees in thousands of persons as monthly averages from January, 1990 to December 2018.

# %% [markdown]
# ### 1. Plot the source data
# Create a line chart of the dataset. Optional: add a title and y-axis label.

# %%
## CODE HERE
ax = df.plot(figsize=(12,8),title='California hospilatity Industry Employees')
ax.set_ylabel("Thounsands of Persons")
# Out:
# Text(0, 0.5, 'Thounsands of Persons')

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 2. Run an ETS Decomposition
# Use an 'additive' model.

# %%
results = seasonal_decompose(df['Employees'],model='add')
results.plot();

# %%
results.seasonal[:3].plot()

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 3. Run <tt>pmdarima.auto_arima</tt> to obtain recommended orders
# This may take awhile as there are a lot of combinations to evaluate.

# %%
result  = auto_arima(df['Employees'],trace=True,seasonal=True,m=12)
result.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=2213.060, Time=4.58 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2974.636, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2707.381, Time=1.63 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2980.790, Time=0.09 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=3.63 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=2340.936, Time=2.71 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=2327.589, Time=7.12 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=16.49 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=8.02 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=2264.870, Time=10.00 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=8.47 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=2210.583, Time=2.46 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=2703.032, Time=0.96 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=2344.522, Time=0.96 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=2213.444, Time=6.51 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=2239.118, Time=7.29 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=2961.373, Time=0.34 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=2596.838, Time=3.24 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=2282.409, Time=4.23 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=7.52 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=2229.077, Time=1.48 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=2236.826, Time=1.54 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=2232.763, Time=2.70 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=2233.847, Time=1.34 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=2228.010, Time=1.78 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=2241.435, Time=3.28 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=2208.504, Time=1.44 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=2704.499, Time=0.59 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=2337.722, Time=0.68 sec
#  ARIMA(1,1,2)(2,0,1)[12]             : AIC=2210.068, Time=4.64 sec
#  ARIMA(1,1,2)(1,0,2)[12]             : AIC=2210.040, Time=4.12 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=2962.870, Time=0.15 sec
#  ARIMA(1,1,2)(0,0,2)[12]             : AIC=2597.699, Time=2.04 sec
#  ARIMA(1,1,2)(2,0,0)[12]             : AIC=2261.075, Time=1.68 sec
#  ARIMA(1,1,2)(2,0,2)[12]             : AIC=2212.253, Time=6.41 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=2227.320, Time=0.90 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=2211.827, Time=0.95 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=2209.563, Time=2.23 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=2210.247, Time=2.06 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=2232.133, Time=0.79 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=2226.229, Time=1.24 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=2208.869, Time=1.51 sec
#  ARIMA(2,1,3)(1,0,1)[12]             : AIC=2211.761, Time=3.08 sec
#
# Best model:  ARIMA(1,1,2)(1,0,1)[12]
# Total fit time: 146.909 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  348
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1098.252
# Date:                              Wed, 23 Feb 2022   AIC                           2208.504
# Time:                                      16:47:53   BIC                           2231.600
# Sample:                                           0   HQIC                          2217.700
#                                               - 348
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9244      0.045     20.569      0.000       0.836       1.013
# ma.L1         -0.9440      0.070    -13.471      0.000      -1.081      -0.807
# ma.L2          0.1288      0.060      2.140      0.032       0.011       0.247
# ar.S.L12       0.9972      0.001    703.740      0.000       0.994       1.000
# ma.S.L12      -0.7490      0.043    -17.321      0.000      -0.834      -0.664
# sigma2        29.2997      1.717     17.062      0.000      25.934      32.665
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                67.43
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.11
# Prob(H) (two-sided):                  0.40   Kurtosis:                         5.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# DON'T WRITE HERE
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  348
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1134.664
# Date:                            Wed, 27 Mar 2019   AIC                           2277.328
# Time:                                    13:12:10   BIC                           2292.726
# Sample:                                         0   HQIC                          2283.459
#                                             - 348
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0477      0.292     -0.163      0.870      -0.620       0.524
# ar.S.L12       0.5291      0.040     13.286      0.000       0.451       0.607
# ar.S.L24       0.4303      0.041     10.453      0.000       0.350       0.511
# sigma2        37.2952      2.157     17.294      0.000      33.068      41.522
# ===================================================================================
# Ljung-Box (Q):                       99.53   Jarque-Bera (JB):                51.67
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.29
# Prob(H) (two-sided):                  0.42   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# You should see a recommended ARIMA Order of (0,1,0) combined with a seasonal order of (2,0,0,12).
# ### 4. Split the data into train/test sets
# Set one year (12 records) for testing. There is more than one way to do this!

# %%
train = df.iloc[:-12]
test = df.iloc[-12:]

# %%
len(test)
# Out:
# 12

# %%
train.head()
# Out:
#             Employees
# Date
# 1990-01-01     1064.5
# 1990-02-01     1074.5
# 1990-03-01     1090.0
# 1990-04-01     1097.4
# 1990-05-01     1108.7

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 5. Fit a SARIMA(0,1,0)(2,0,0,12) model to the training set

# %%
model = SARIMAX(train['Employees'],order=(0,1,0),seasonal_order=(2,0,0,12))

# %%
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Employees   No. Observations:                  336
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1095.407
# Date:                            Wed, 23 Feb 2022   AIC                           2196.814
# Time:                                    16:51:51   BIC                           2208.256
# Sample:                                01-01-1990   HQIC                          2201.375
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.5204      0.040     13.051      0.000       0.442       0.599
# ar.S.L24       0.4385      0.041     10.593      0.000       0.357       0.520
# sigma2        37.1907      2.165     17.175      0.000      32.947      41.435
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                56.66
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.35
# Prob(H) (two-sided):                  0.74   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# DON'T WRITE HERE
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                          Employees   No. Observations:                  336
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1095.407
# Date:                            Wed, 27 Mar 2019   AIC                           2196.814
# Time:                                    13:12:24   BIC                           2208.256
# Sample:                                01-01-1990   HQIC                          2201.375
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.5204      0.040     13.051      0.000       0.442       0.599
# ar.S.L24       0.4385      0.041     10.593      0.000       0.357       0.520
# sigma2        37.1907      2.165     17.175      0.000      32.947      41.435
# ===================================================================================
# Ljung-Box (Q):                      102.80   Jarque-Bera (JB):                56.66
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.35
# Prob(H) (two-sided):                  0.74   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### 6. Obtain predicted values

# %%
start = len(train)
end = len(train)+len(test)-1

# %%
predictions = result.predict(start,end,typ='level').rename('Sarima Pred')

# %%
predictions
# Out:
# 2018-01-01    1921.900950
# 2018-02-01    1944.277732
# 2018-03-01    1963.474255
# 2018-04-01    1990.272681
# 2018-05-01    2008.694933
# 2018-06-01    2025.919654
# 2018-07-01    2034.256703
# 2018-08-01    2034.306381
# 2018-09-01    2014.147428
# 2018-10-01    2013.689596
# 2018-11-01    2005.091610
# 2018-12-01    2006.280953
# Freq: MS, Name: Sarima Pred, dtype: float64

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 7. Plot predictions against known values
# Optional: add a title and y-axis label.

# %%
test['Employees'].plot(figsize=(12,10),legend=True)
predictions.plot(figsize=(12,10),legend=True)

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 8. Evaluate the Model using MSE and RMSE
# You can run both from the same cell if you want.

# %%
"SARIMA(0,1,0)(2,0,0,12)"
print(mean_squared_error(test['Employees'],predictions))
print(rmse(test['Employees'],predictions))
# Out:
# 182.85065974365935
# 13.52222835717765

# %%
test.iloc[0]['Employees']
# Out:
# 1916.8

# %%
# DON'T WRITE HERE
# Out:
# SARIMA(0,1,0)(2,0,0,12) MSE Error: 182.8506646
# SARIMA(0,1,0)(2,0,0,12) RMSE Error: 13.52222854

# %% [markdown]
# ### 9. Retrain the model on the full data and forecast one year into the future

# %%
model = SARIMAX(df['Employees'],order=(0,1,0),seasonal_order=(2,0,0,12))
result= model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Employees   No. Observations:                  348
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1134.677
# Date:                            Wed, 23 Feb 2022   AIC                           2275.353
# Time:                                    17:00:42   BIC                           2286.901
# Sample:                                01-01-1990   HQIC                          2279.951
#                                      - 12-01-2018
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.5293      0.040     13.352      0.000       0.452       0.607
# ar.S.L24       0.4297      0.041     10.416      0.000       0.349       0.511
# sigma2        37.3116      2.152     17.335      0.000      33.093      41.530
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                51.83
# Prob(Q):                              0.78   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.29
# Prob(H) (two-sided):                  0.40   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
predictions = result.predict(len(df),len(df)+12,typ="level")

# %%
predictions.head()
# Out:
# 2019-01-01    1960.423879
# 2019-02-01    1985.270286
# 2019-03-01    2005.854537
# 2019-04-01    2027.323764
# 2019-05-01    2045.564010
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 10. Plot the forecasted values alongside the original data
# Optional: add a title and y-axis label.

# %%
df['Employees'].plot(figsize=(12,5),legend=True)
predictions.plot(figsize=(12,5),legend=True)

# %%
# DON'T WRITE HERE

# %% [markdown]
# ## Great job!
