# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal266/Algo_Practice/blob/main/yolo_tes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pytesseract
import os

# %%
# !wget https://www.icst.pku.edu.cn/cpdp/docs/20190424190300041510.zip

# %%
cd /content/drive/MyDrive

# %%
# !unzip 20190424190300041510.zip

# %%
# !wget 'https://raw.githubusercontent.com/jakkcoder/training_yolo_custom_object_detection_files/main/creating-files-data-and-name.py'
# Out:
# --2021-11-07 03:26:48--  https://raw.githubusercontent.com/jakkcoder/training_yolo_custom_object_detection_files/main/creating-files-data-and-name.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2551 (2.5K) [text/plain]
# Saving to: ‘creating-files-data-and-name.py’
#
# creating-files-data 100%[===================>]   2.49K  --.-KB/s    in 0s
#
# 2021-11-07 03:26:48 (27.3 MB/s) - ‘creating-files-data-and-name.py’ saved [2551/2551]

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/marmot_dataset_v1.0
# Out:
# /content/drive/MyDrive/marmot_dataset_v1.0

# %%
# !wget  'https://raw.githubusercontent.com/jakkcoder/training_yolo_custom_object_detection_files/main/creating-train-and-test-txt-files.py'
# Out:
# --2021-11-07 03:27:20--  https://raw.githubusercontent.com/jakkcoder/training_yolo_custom_object_detection_files/main/creating-train-and-test-txt-files.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3049 (3.0K) [text/plain]
# Saving to: ‘creating-train-and-test-txt-files.py’
#
# creating-train-and- 100%[===================>]   2.98K  --.-KB/s    in 0s
#
# 2021-11-07 03:27:20 (31.6 MB/s) - ‘creating-train-and-test-txt-files.py’ saved [3049/3049]

# %%
cd /content/drive/MyDrive/receipt_dataset
# Out:
# /content/drive/MyDrive/receipt_dataset

# %%
cat creating-files-data-and-name.py

# %%
cat creating-train-and-test-txt-files.py

# %%
# !python3 creating-train-and-test-txt-files.py

# %%
# !python3 creating-files-data-and-name.py

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
pwd
# Out:
# '/content/drive/My Drive/marmot_dataset_v1.0'

# %%
# !cat voc_to_txt.py

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15316, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 15316 (delta 3), reused 2 (delta 2), pack-reused 15312
# Receiving objects: 100% (15316/15316), 13.71 MiB | 6.67 MiB/s, done.
# Resolving deltas: 100% (10408/10408), done.
# Checking out files: 100% (2043/2043), done.

# %%
# !wget https://raw.githubusercontent.com/ssaru/convert2Yolo/master/requirements.txt
# Out:
# --2021-10-11 07:30:11--  https://raw.githubusercontent.com/ssaru/convert2Yolo/master/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 144 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]     144  --.-KB/s    in 0s
#
# 2021-10-11 07:30:11 (6.02 MB/s) - ‘requirements.txt’ saved [144/144]

# %%
# !git clone https://github.com/ssaru/convert2Yolo.git
# Out:
# Cloning into 'convert2Yolo'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 215 (delta 4), reused 6 (delta 4), pack-reused 201
# Receiving objects: 100% (215/215), 1002.72 KiB | 7.21 MiB/s, done.
# Resolving deltas: 100% (89/89), done.

# %%
cd convert2Yolo/
# Out:
# /content/drive/My Drive/marmot_dataset_v1.0/convert2Yolo

# %%
# !python3 example.py --datasets VOC --img_path /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw --label /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw --convert_output_path /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw --img_type ".bmp" --manifest_path ./ --cls_list_file /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw/classes.names
# Out:
# VOC Parsing Result : False, msg : ERROR : 'utf-8' codec can't decode byte 0x98 in position 3: invalid start byte, moreInfo : <class 'UnicodeDecodeError'>	Format.py	250

# %%
# !pip3 install -r requirements.txt

# %%
# !python3 voc_to_txt.py --datasets VOC --img_path /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw --label /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw --convert_output_path /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw --img_type ".bmp" --manifest_path ./ --cls_list_file /content/drive/MyDrive/marmot_dataset_v1.0/data/English/Positive/Raw/classes.names
# Out:
# Traceback (most recent call last):
#   File "voc_to_txt.py", line 10, in <module>
#     from Format import VOC, COCO, UDACITY, KITTI, YOLO
# ModuleNotFoundError: No module named 'Format'

# %%
cd ../
# Out:
# /content/drive/My Drive/marmot_dataset_v1.0

# %%
# !wget https://github.com/rafaelymz/YOLO_transfer_learning/raw/master/yolo_transfer_learning/marmot_data_utils.py

# %%
# !python3 marmot_data_utils.py

# %%
cd /content/drive/MyDrive/marmot_dataset_v1.0
# Out:
# /content/drive/MyDrive/marmot_dataset_v1.0

# %%
# !chmod +x ./darknet/darknet

# %%
cd darknet
# Out:
# /content/drive/My Drive/receipt_dataset/darknet

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# !chmod +x ./darknet/darknet

# %%
cd ../
# Out:
# /content/drive/My Drive/receipt_dataset

# %%
# !./darknet/darknet detector train /content/drive/MyDrive/receipt_dataset/labelled_data.data /content/drive/MyDrive/receipt_dataset/darknet/cfg/yolo_obj_cust.cfg /content/drive/MyDrive/receipt_dataset/yolov4.conv.137 -dont_show

# %%
# Out:
# '/content/drive/My Drive/marmot_dataset_v1.0'

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
pwd
# Out:
# '/content/drive/My Drive/receipt_dataset'

# %%
# !/content/drive/MyDrive/receipt_dataset/darknet/darknet detector test /content/drive/MyDrive/receipt_dataset/labelled_data.data /content/drive/MyDrive/receipt_dataset/darknet/cfg/yolo_obj_cust.cfg /content/drive/MyDrive/receipt_dataset/backup/yolo_obj_cust_last.weights /content/drive/MyDrive/receipt_dataset/1125-receipt.jpg -dont_show -out result.txt

# %%
img = cv2.imread('/content/drive/MyDrive/receipt_dataset/1054-receipt.jpg')
img.shape[0]
# Out:
# 1000

# %%
# !sudo add-apt-repository ppa:alex-p/tesseract-ocr

# %%
# !sudo apt-get update
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# !sudo pip install pytesseract

# %%
# !git clone https://github.com/theAIGuysCode/yolov4-custom-functions.git
# Out:
# Cloning into 'yolov4-custom-functions'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 251 (delta 3), reused 0 (delta 0), pack-reused 241
# Receiving objects: 100% (251/251), 62.01 MiB | 14.60 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Checking out files: 100% (64/64), done.

# %%
cd yolov4-custom-functions/
# Out:
# /content/drive/My Drive/receipt_dataset/yolov4-custom-functions

# %%
! pip uninstall tensorflow 
! pip install tensorflow==2.3.0

# %%
cd /content/drive/MyDrive/receipt_dataset/yolov4-custom-functions
# Out:
# /content/drive/MyDrive/receipt_dataset/yolov4-custom-functions

# %%
# !pip install -r requirements-gpu.txt

# %%
ls /content/drive/MyDrive/receipt_dataset/yolov4-custom-functions/detections/crop/1125-receipt

# %%
pwd
# Out:
# '/content/drive/My Drive/receipt_dataset'

# %%
# !/content/drive/MyDrive/receipt_dataset/darknet/darknet detector test /content/drive/MyDrive/receipt_dataset/labelled_data.data /content/drive/MyDrive/receipt_dataset/darknet/cfg/yolo_obj_cust.cfg /content/drive/MyDrive/receipt_dataset/backup/yolo_obj_cust_last.weights -dont_show -out result.json < ./testing_img.txt
f = open('/content/drive/MyDrive/receipt_dataset/result.json', "r")
a = json.loads(f.read())
path = a[0]["filename"]
img = cv2.imread(path)
height = img.shape[0]
width = img.shape[1]
print(height,width)
cv2_imshow(img)
cv2_imshow(cv2.imread("/content/drive/MyDrive/receipt_dataset/predictions.jpg"))
objects = a[0]["objects"]
for i in objects:
  titless = i["name"]
  print()
  xcnet = i["relative_coordinates"]["center_x"]
  ycnet = i["relative_coordinates"]["center_y"]
  hih = i["relative_coordinates"]["height"]
  wid = i["relative_coordinates"]["width"]
  xcnet= xcnet*width
  ycnet= ycnet*height
  hih= hih*height
  wid= wid*width
  xmin = int(xcnet - wid/2)
  ymin = int(ycnet - hih/2)
  xmax = int(xcnet + wid/2)
  ymax = int(ycnet + hih/2)
  # print(xmin,xmax,ymin,ymax)
  # print(int(xcnet),int(ycnet),int(hih),int(wid))
  # print(img)
  cropped_image = img[ymin:ymax,xmin:xmax]

  # print(cropped_image)
  cv2_imshow(cropped_image)
  pathss = f"/content/drive/MyDrive/receipt_dataset/{titless}.jpg"
  if (os.path.exists(pathss)):
    print("order numeber ")
    cv2.imwrite(f"{titless}_{objects.index(i)}.jpg",cropped_image)
  else:
    cv2.imwrite(f"{titless}.jpg",cropped_image)

  custom_config = r'--oem 3 --psm 6'
  pytesseract.image_to_string(cropped_image, config=custom_config)
# print(a[0]["objects"][1]["name"])
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# ...

# %%
import cv2
import numpy as np

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 



image = cv2.imread('/content/drive/MyDrive/receipt_dataset/title.jpg')

gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
cv2_imshow(gray)
cv2_imshow(opening)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=314x90 at 0x7F755F3531D0>
# <PIL.Image.Image image mode=L size=314x90 at 0x7F755F3537D0>
# <PIL.Image.Image image mode=L size=314x90 at 0x7F755F3533D0>

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray)
# Out:
# ' \n\x0c'
