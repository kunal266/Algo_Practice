# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Time Series with Pandas Project Exercise
#
# For this exercise, answer the questions below given the dataset: https://fred.stlouisfed.org/series/UMTMVS
#
# This dataset is the Value of Manufacturers' Shipments for All Manufacturing Industries.

# %% [markdown]
# **Import any necessary libraries.**

# %%
# %pip install pandas
# %pip install pandas
# %pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# CODE HERE
import numpy as numpy
import pandas as pd
import matplotlib

# %% [markdown]
# **Read in the data UMTMVS.csv file from the Data folder**

# %%
# CODE HERE
df = pd.read_csv('/workspace/Algo_Practice/UDEMY_TSA_FINAL/Data/UMTMVS.csv', encoding='utf8')

# %% [markdown]
# **Check the head of the data**

# %%
# CODE HERE
df.head()
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %%
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %% [markdown]
# **Set the DATE column as the index.**

# %%
# CODE HERE

# %%
df.set_index('DATE',inplace=True)
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %% [markdown]
# **Check the data type of the index.**

# %%
# CODE HERE
df.index
# Out:
# Index(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#        '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01', '1992-10-01',
#        ...
#        '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'],
#       dtype='object', name='DATE', length=325)

# %%
# Out:
# Index(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#        '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01', '1992-10-01',
#        ...
#        '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'],
#       dtype='object', name='DATE', length=325)

# %% [markdown]
# **Convert the index to be a datetime index. Note, there are many, many correct ways to do this!**

# %%
# CODE HERE
df.index=pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %%
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %% [markdown]
# **Plot out the data, choose a reasonable figure size**

# %%
# CODE HERE
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# **What was the percent increase in value from Jan 2009 to Jan 2019?**

# %%
#CODE HERE
((df.loc['2019-01-01']-df.loc['2009-01-01'])/df.loc['2009-01-01'])*100
# Out:
# UMTMVS    38.472149
# dtype: float64

# %%
# Out:
# UMTMVS    38.472149
# dtype: float64

# %% [markdown]
# **What was the percent decrease from Jan 2008 to Jan 2009?**

# %%
#CODE HERE
((df.loc['2009-01-01']-df.loc['2008-01-01'])/df.loc['2008-01-01'])*100
# Out:
# UMTMVS   -22.022775
# dtype: float64

# %%
# Out:
# UMTMVS   -22.022775
# dtype: float64

# %% [markdown]
# **What is the month with the least value after 2005?** [HINT](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmin.html)

# %%
#CODE HERE
# df2 = df.loc['2005-01-01':]
# df2.loc[lambda df1: (df1['UMTMVS']== min(df1['UMTMVS']))]
df.loc['2005-01-01':].idxmin()
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %% [markdown]
# **What 6 months have the highest value?**

# %%
# CODE HERE
df.sort_values(by='UMTMVS',ascending=False).head(5)
# Out:
#               UMTMVS
# DATE
# 2018-08-01  529157.0
# 2018-10-01  527031.0
# 2018-06-01  525660.0
# 2018-03-01  518285.0
# 2018-09-01  516992.0

# %%
# Out:
#               UMTMVS    Yearly Mean
# DATE
# 2018-08-01  529157.0  490453.500000
# 2018-10-01  527031.0  496482.333333
# 2018-06-01  525660.0  483611.000000
# 2018-03-01  518285.0  474351.250000
# 2018-09-01  516992.0  493075.583333

# %% [markdown]
# **How many millions of dollars in value was lost in 2008? (Another way of posing this question is what was the value difference between Jan 2008 and Jan 2009)**

# %%
# CODE HERE
(df.loc['2008-01-01']-df.loc['2009-01-01'])
# Out:
# UMTMVS    95206.0
# dtype: float64

# %%
# Out:
# UMTMVS    95206.0
# dtype: float64

# %% [markdown]
# **Create a bar plot showing the average value in millions of dollars per year**

# %%
# CODE HERE
df.resample(rule='A').mean().plot.bar(figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# **What year had the biggest increase in mean value from the previous year's mean value? (Lots of ways to get this answer!)**
#
# [HINT for a useful method](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.idxmax.html)

# %%
# CODE HERE
max(df.resample(rule='A').mean())
# Out:
# 'UMTMVS'

# %%
df.resample(rule='A').mean().idxmax()
# Out:
# UMTMVS   2018-12-31
# dtype: datetime64[ns]

# %%
yearly_data = df.resample('Y').mean()
yearly_data_shift = yearly_data.shift(1)
yearly_data.head()
# Out:
#                    UMTMVS
# DATE
# 1992-12-31  242002.000000
# 1993-12-31  251708.083333
# 1994-12-31  269842.666667
# 1995-12-31  289973.083333
# 1996-12-31  299765.666667

# %%
# Out:
#                    UMTMVS
# DATE
# 1992-12-31  242002.000000
# 1993-12-31  251708.083333
# 1994-12-31  269842.666667
# 1995-12-31  289973.083333
# 1996-12-31  299765.666667

# %%
# Out:
# Timestamp('2011-12-31 00:00:00', freq='A-DEC')

# %% [markdown]
# **Plot out the yearly rolling mean on top of the original data. Recall that this is monthly data and there are 12 months in a year!**

# %%
# CODE HERE

# %%
df['UMTMVS'].plot(figsize=(20,10))
df.rolling(window=12).mean()['UMTMVS'].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# **BONUS QUESTION (HARD).**
#
# **Some month in 2008 the value peaked for that year. How many months did it take to surpass that 2008 peak? (Since it crashed immediately after this peak) There are many ways to get this answer. NOTE: I get 70 months as my answer, you may get 69 or 68, depending on whether or not you count the start and end months. Refer to the video solutions for full explanation on this.**

# %%
#CODE HERE
max_value = (max(df.loc['2008-01-01':'2008-12-01','UMTMVS']))
max_value
# Out:
# 510081.0

# %%
first_peak = df.loc['2008-01-01':'2008-12-01','UMTMVS'].idxmax()
str(first_peak)
# Out:
# '2008-06-01 00:00:00'

# %%
df.loc[(df.loc['2008-01-01':'2008-12-01'].idxmax()).strftime():]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1610/1860041784.py in <module>
# ----> 1 df.loc[(df.loc['2008-01-01':'2008-12-01'].idxmax()).strftime():]
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strftime'

# %%
df.loc[str(first_peak):,'UMTMVS']
# Out:
# DATE
# 2008-06-01    510081.0
# 2008-07-01    476948.0
# 2008-08-01    482530.0
# 2008-09-01    471799.0
# 2008-10-01    450521.0
#                 ...
# 2018-09-01    516992.0
# 2018-10-01    527031.0
# 2018-11-01    495901.0
# 2018-12-01    490076.0
# 2019-01-01    466791.0
# Name: UMTMVS, Length: 128, dtype: float64

# %%
df.loc[str(first_peak):,df['UMTMVS']>max_value]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /tmp/ipykernel_1610/147205382.py in <module>
# ----> 1 df.loc[str(first_peak):,df['UMTMVS']>max_value]
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
df[df.loc[str(first_peak):]>=max_value].dropna()
# Out:
#               UMTMVS
# DATE
# 2008-06-01  510081.0
# 2014-03-01  513700.0
# 2014-06-01  516935.0
# 2014-09-01  512988.0
# 2018-03-01  518285.0
# 2018-05-01  515105.0
# 2018-06-01  525660.0
# 2018-08-01  529157.0
# 2018-09-01  516992.0
# 2018-10-01  527031.0

# %%
len(df.loc['2008-06-01':'2014-03-01'])
# Out:
# 70

# %% [markdown]
# # GREAT JOB!
